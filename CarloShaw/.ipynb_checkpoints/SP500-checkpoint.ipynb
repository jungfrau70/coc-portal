# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

from concurrent import futures
import datetime as dt
import numpy as np
from scipy.stats import gaussian_kde
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

data_dir = "./data/mostattractive_stocks"
os.makedirs(data_dir, exist_ok=True)

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')

# %%
sp500_df = tables[0]
second_table = tables[1]
print(sp500_df.shape)

# rename symbol to escape symbol error
sp500_df["Symbol"] = sp500_df["Symbol"].map(lambda x: x.replace(".", "-"))
sp500_df.to_csv("./data/SP500_20230104.csv", index=False)
sp500_df = pd.read_csv("./data/SP500_20230104.csv")
print(sp500_df.shape)
sp500_tickers = list(sp500_df["Symbol"])
sp500_df.head()
# Out:
# (503, 9)
# (503, 9)
#   Symbol     Security SEC filings             GICS Sector  \
# 0    MMM           3M     reports             Industrials
# 1    AOS  A. O. Smith     reports             Industrials
# 2    ABT       Abbott     reports             Health Care
# 3   ABBV       AbbVie     reports             Health Care
# 4    ACN    Accenture     reports  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota       1976-08-09
# 1               Building Products     Milwaukee, Wisconsin       2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 3                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1    91142         1916
# 2     1800         1888
# 3  1551152  2013 (1888)
# 4  1467373         1989

# %%
""" set the download window """
start_date = "2017-01-01"
end_date = "2017-04-30"

bad_names = [] # to keep track of failed queries

def download_stock(stock):
    try: 
        # download dataframe
        data = pdr.get_data_yahoo(stock, start=start_date, end=end_date)
        data['Name'] = stock
        output_name = f"{data_dir}//{stock}.csv"
        data.to_csv(output_name)
    except BaseException:
        bad_names.append(stock)
        print('bad: %s' % (stock))

# %%
# set the maximum thread number
max_workers = 20
now = dt.datetime.now()
path_failed_queries = f'{data_dir}/failed_queries.txt'
if os.path.exists(path_failed_queries):
    with open(path_failed_queries) as f:
        failed_queries = f.read().split("\n")[:-1]
        sp500_tickers_ = failed_queries
else:
    sp500_tickers_ = sp500_tickers
print("number of stockes to download:", len(sp500_tickers_))
# Out:
# number of stockes to download: 503

# %%
# in case a smaller number of stocks than threads was passed in
workers = min(max_workers, len(sp500_tickers_))

# %%
with futures.ThreadPoolExecutor(workers) as executor:
    res = executor.map(download_stock, sp500_tickers_)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: ABBV
# bad: ADP
# bad: AMT
# bad: ABC
# bad: LNT
# bad: ADM
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# bad: AES
# bad: AMGN
# [*********************100%***********************]  1 of 1 completed
#
# bad: AOS
# bad: ADI
# [*********************100%***********************]  1 of 1 completed
#
# bad: ALLE
# bad: ADBE
# [*********************100%***********************]  1 of 1 completed
#
# bad: AMP
# bad: GOOG
# bad: AKAM
# bad: AAPL
# bad: ARE
# bad: AON
# bad: GOOGL
# bad: APH
# bad: AXP
# bad: ALL
# bad: ACN
# bad: A
# bad: MMM
# bad: AWK
# bad: ACGL
# bad: AMZN
# bad: ATVI
# bad: APA
# bad: AAP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: AMCR
# bad: APD
# bad: ALGN
# bad: BBY
# bad: AIZ
# bad: WRB
# bad: AJG
# bad: ALK
# bad: CDW
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
# bad: ABT
# bad: BF-B
# bad: BXP
# bad: BAC
# bad: ANET
# bad: BKNG
# bad: AZO
# bad: AMD
# bad: BIO
# bad: BIIB
# bad: CBOE
# bad: CHRW
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
# bad: ALB
# bad: BDX
# bad: BBWI
# bad: AAL
# bad: CPB
# bad: AVY
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# bad: AIG
# [*********************100%***********************]  1 of 1 completed
# bad: ANSS
# bad: CDAY
# bad: AMAT
# bad: ATO
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: MO
# bad: APTV
# bad: BRK-B
# bad: BMY
# bad: CLX
# bad: BRO
# [*********************100%***********************]  1 of 1 completed
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: BAX
# bad: AEP
# bad: CSCO
# bad: AFL
# bad: AME
# bad: ADSK
# bad: T
# bad: AEE
# bad: CE
# bad: CPT
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
# bad: SCHW
# bad: CF
# bad: BALL
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: KO
# bad: CDNS
# bad: COF
# bad: CI
# bad: BKR
# bad: CZR
# bad: BA
# bad: CTAS
# bad: CTLT
# bad: CMCSA
# bad: CCI
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
# bad: CHD
# bad: DRI
# bad: CSGP
# bad: BK
# bad: CBRE
# bad: CVX
# bad: CB
# bad: CME
# bad: CNP
# bad: BLK
# bad: CARR
# bad: AVGO
# bad: DHR
# bad: CTVA
# bad: CSX
# [*********************100%***********************]  1 of 1 completedbad: BSX
#
# bad: CHTR
#
# bad: COST
#
# bad: KMX
#
# bad: CCL
#
# bad: GLW
#
# bad: DPZ
#
# bad: CL
#
# bad: DAL
#
# bad: COO
#
# bad: BWA
#
# bad: CMS
#
# bad: D
#
# bad: TECH
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: CTSH
# bad: CPRT
# bad: CINF
# bad: DHI
# bad: AVB
# bad: CFG
# bad: CTRA
# bad: XRAY
# bad: CNC
# bad: CAH
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
# bad: DD
# bad: BR
# bad: CMG
# bad: C
# bad: EXPE
# bad: ED
# bad: DFS
# bad: DUK
# bad: DVN
# bad: STZ
# bad: DLR
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: EVRG
# bad: DISH
# bad: EXR
# bad: CMA
# bad: DOW
# bad: EQIX
# bad: DTE
# bad: COP
# bad: LLY
# bad: FITB
# bad: CMI
# bad: EMN
# bad: CRL
# bad: DXC
# bad: EW
# bad: CAG
# bad: DOV
# bad: ECL
# bad: ETN
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: EIX
# bad: ENPH
# bad: EXPD
# bad: DXCM
# bad: GEHC
# bad: CAT
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# bad: RE
# bad: DG
# bad: DVA
# bad: FDX
# bad: DE
# bad: EA
# bad: FE
# bad: FFIV
# bad: DIS
# bad: ETSY
# bad: EPAM
# bad: EBAY
# bad: FANG
# bad: EQT
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: GE
# bad: FIS
# bad: ES
# bad: EQR
# bad: FSLR
# bad: DLTR
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# bad: GPC
# bad: ESS
# bad: EOG
# bad: FTV
# bad: HLT
# bad: HES
# bad: EL
# bad: CEG
# bad: FCX
# bad: FISV
# bad: EXC
# bad: XOM
# bad: ELV
# bad: FOXA
# bad: ISRG
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
# bad: EMR
# bad: HAL
# bad: FMC
# bad: ICE
# bad: HBAN
# bad: GS
# bad: HSIC
# bad: CVS
# bad: FTNT
# bad: GRMN
# bad: FLT
# bad: GNRC
# bad: FDS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
# bad: FAST
# bad: MTB
# bad: IR
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: HRL
# bad: IEX
# bad: IFF
# bad: FOX
# bad: HIG
# bad: F
# bad: HST
# bad: GILD
# bad: ETR
# bad: K
# bad: LDOS
# bad: EFX
# bad: IT
# bad: GIS
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: HCA
# bad: BEN
# bad: IQV
# bad: LMT
# bad: INCY
# bad: HPQ
# bad: HSY
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
# bad: KEY
# bad: FRC
# [*********************100%***********************]  1 of 1 completed
#
# bad: J
# bad: ILMN
# [*********************100%***********************]  1 of 1 completed
#
# bad: HUM
# bad: GEN
# bad: HPE
# bad: IBM
# bad: FRT
# bad: LOW
# bad: INTC
# bad: IPG
# bad: MPC
# bad: GD
# bad: HAS
# bad: IVZ
# bad: HON
# bad: HD
# bad: GL
# bad: GM
# bad: HII
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
# bad: PEAK
# bad: JPM
# bad: KMI
# bad: ITW
# bad: KLAC
# bad: JNJ
# bad: KHC
# bad: JKHY
# bad: IP
# bad: LNC
# bad: LH
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
# bad: MCHP
# bad: LW
# bad: MRO
# bad: TAP
# bad: HOLX
# bad: MSFT
# bad: LEN
# bad: LKQ
# bad: MU
# bad: LYV
# bad: HWM
# bad: IRM
# bad: MMC
# bad: MOH
# bad: MAR
# bad: GPN
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: LYB
# bad: MKTX
# bad: LUMN
# bad: NWSA
# bad: MAS
# bad: KIM
# bad: ORLY
# bad: NFLX
# bad: MCD
# bad: MLM
# bad: IDXX
# bad: JBHT
# bad: JCI
# bad: KMB
# bad: KEYS
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: LHX
# bad: MPWR
# bad: MAA
# bad: MS
# bad: ON
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
# bad: KR
# bad: MSCI
# bad: MKC
# bad: MRK
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: KDP
# bad: MHK
# bad: L
# bad: MDLZ
# bad: LIN
# bad: INTU
# bad: MET
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
# bad: NVDA
# bad: PAYX
# bad: MGM
# bad: PARA
# bad: ROL
# bad: NCLH
# bad: PM
# bad: MSI
# bad: NEE
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
# bad: MNST
# bad: JNPR
# bad: MTCH
# bad: NVR
# bad: OGN
# bad: NKE
# bad: NXPI
# bad: LRCX
# bad: MOS
# bad: PHM
# bad: RTX
# bad: MCK
# bad: NWL
# bad: MRNA
# bad: NDAQ
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: OXY
# bad: MDT
# bad: NOC
# bad: NUE
# bad: NSC
# bad: MCO
# bad: MTD
# bad: MA
# bad: ORCL
# bad: PXD
# bad: PYPL
# bad: RHI
# bad: PCG
# bad: OKE
# bad: RJF
# bad: PCAR
# bad: META
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: PPL
# bad: INVH
# [*********************100%***********************]  1 of 1 completed
#
# bad: PSA
# bad: PKG
# bad: RL
# bad: PNR
# bad: REGN
# bad: SBAC
# bad: NDSN
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: PEG
# bad: QRVO
# bad: NTRS
# bad: SHW
# bad: PTC
# bad: RCL
# bad: PEP
# bad: PH
# bad: PPG
# bad: NI
# bad: PFE
# bad: PKI
# bad: PWR
# bad: PLD
# bad: NWS
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
# bad: SWK
# bad: PFG
# bad: RF
# bad: SIVB
# bad: O
# bad: TGT
# bad: PNC
# bad: SEDG
# bad: SJM
# bad: NTAP
# bad: POOL
# bad: TMUS
# bad: ROST
# bad: PSX
# bad: REG
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: PAYC
# bad: SYK
# bad: SNA
# bad: DGX
# bad: CRM
# bad: NRG
# bad: SPG
# bad: RSG
# bad: QCOM
# bad: TFX
# bad: TROW
# bad: NEM
# bad: ROP
# bad: SBUX
# bad: TSLA
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: TDG
# bad: SYY
# bad: TER
# bad: VLO
# bad: UDR
# bad: SYF
# bad: TPR
# bad: TFC
# bad: PG
# bad: NOW
# bad: TXN
# bad: TTWO
# bad: TRV
# bad: TMO
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: PGR
# bad: OTIS
# bad: SEE
# bad: VRTX
# bad: SRE
# bad: STX
# bad: URI
# bad: UAL
# bad: STT
# bad: TT
# bad: STLD
# bad: VICI
# bad: PRU
# bad: PNW
# bad: ULTA
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: UNP
# [*********************100%***********************]  1 of 1 completed
# bad: LUV
# bad: RMD
# bad: UNH
# bad: TSCO
# bad: UHS
# bad: TRGP
# bad: SNPS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# bad: WM
# bad: TDY
# bad: VRSN
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: VMC
# bad: WST
# bad: WTW
# bad: WY
# bad: WHR
# bad: TXT
# bad: TRMB
# bad: WEC
# bad: TSN
# bad: TJX
# bad: TEL
# bad: SWKS
# bad: SO
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
# bad: ODFL
# bad: ROK
# bad: GWW
# bad: VTR
# bad: XEL
# bad: WBA
# bad: LVS
# bad: VZ
# bad: WELL
# bad: YUM
# bad: UPS
# bad: USB
# bad: V
# bad: ZBRA
# bad: SBNY
# bad: ZION
# bad: TYL
# bad: STE
# bad: OMC
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: WYNN
# bad: ZBH
# bad: WAT
# bad: ZTS
# bad: WBD
# bad: VFC
# bad: WMT
# bad: VRSK
# bad: WMB
# bad: SPGI
# bad: SLB
# bad: WFC
# bad: WDC
# bad: WRK
# bad: WAB
# bad: VTRS
# bad: XYL

# %%
with futures.ThreadPoolExecutor(workers) as executor:
    res = executor.map(download_stock, sp500_tickers_)
    
""" Save failed queries to a text file to retry """
if len(bad_names) > 0:
    with open(path_failed_queries, 'w') as outfile:
        for name in bad_names:
            outfile.write(name + "\n")
                          
finish_time = dt.datetime.now()
duration = finish_time - now
minutes, seconds = divmod(duration.seconds, 60)
print(f'The threaded script took {minutes} minutes and {seconds} seconds to run.')
print(f'{len(bad_names)} stocks failed: ', bad_names)
# Out:
# number of stockes to download: 503
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
# bad: ALL
# bad: AKAM
# bad: GOOGL
# bad: AMZN
# bad: LNT
# bad: AAP
# bad: MMM
# bad: AES
# bad: ADBE
# bad: A
# bad: GOOG
# bad: ADP
# bad: AMT
# bad: ABC
# bad: ABBV
# bad: AXP
# bad: AMGN
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: ADM
# bad: APA
# bad: AON
# bad: BBY
# bad: AOS
# bad: ALLE
# bad: ADI
# bad: AAPL
# bad: ACN
# bad: ACGL
# bad: AWK
# bad: AMP
# bad: APH
# bad: ARE
# bad: ATVI
# bad: APD
# bad: AAL
# bad: BAC
# bad: AJG
# bad: AFL
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: ALB
# bad: BIO
# bad: ATO
# bad: AMCR
# bad: AIZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: CDW
# bad: ALGN
# bad: CHRW
# bad: ALK
# bad: WRB
# bad: ANET
# bad: AEE
# bad: ABT
# bad: BKNG
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: BBWI
# bad: CBOE
# bad: BF-B
# bad: AZO
# bad: MO
# bad: BXP
# bad: APTV
# bad: BIIB
# bad: AMD
# bad: AMAT
# bad: CPB
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
# bad: BMY
# bad: ANSS
# bad: AIG
# bad: BDX
# bad: AVY
# bad: CSCO
# bad: CI
# bad: BAX
# bad: AEP
# bad: CTLT
# bad: BK
# bad: T
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
# bad: CDAY
# bad: CPT
# [*********************100%***********************]  1 of 1 completed
#
# bad: CLX
# bad: BRO
# bad: CTAS
# bad: AME
# bad: CE
# bad: BSX
# bad: BRK-B
# bad: CNC
# bad: CB
# bad: ADSK
# bad: BKR
# bad: DHR
# bad: COF
# bad: BALL
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: CMCSA
# bad: CDNS
# [*********************100%***********************]  1 of 1 completed
#
# bad: CFG
# bad: CBRE
# bad: KO
# bad: SCHW
# bad: CF
# bad: BA
# bad: CCI
# bad: CHD
# bad: BLK
# bad: CZR
# bad: CME
# bad: CSX
# bad: CVX
# bad: CPRT
# bad: AVGO
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: CNP
# [*********************100%***********************]  1 of 1 completed
# bad: DRI
# bad: CSGP
# bad: DD
# bad: CTVA
# bad: CARR
# bad: CHTR
# bad: COST
# bad: CCL
# bad: GLW
# bad: CL
# bad: KMX
# bad: COO
# bad: AVB
# bad: TECH
# bad: D
# bad: BWA
# bad: DAL
# bad: CMS
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: DPZ
# bad: ED
# bad: CAH
# bad: CAG
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: BR
# bad: ETN
# bad: XRAY
# bad: CTSH
# bad: STZ
# bad: CMG
# bad: DTE
# bad: CINF
# bad: DHI
# bad: DISH
# bad: CTRA
# bad: EXR
# bad: CMA
# bad: CMI
# bad: DVN
# bad: COP
# bad: C
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
# bad: DFS
# bad: EXPE
# bad: DUK
# bad: DXC
# bad: DLR
# bad: CRL
# bad: DOV
# bad: FITB
# bad: EW
# bad: CAT
# bad: LLY
# bad: ECL
# bad: EQIX
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
# bad: DOW
# bad: EVRG
# bad: EMN
# bad: FANG
# bad: EQT
# bad: ETSY
# bad: DXCM
# bad: EA
# bad: EXPD
# bad: DE
# bad: ELV
# bad: EOG
# bad: DIS
# bad: DLTR
# bad: EXC
# bad: CEG
# bad: ENPH
# bad: DVA
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: EIX
# bad: DG
# bad: GEHC
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: RE
# [*********************100%***********************]  1 of 1 completed
# bad: FDX
# [*********************100%***********************]  1 of 1 completed
# bad: FFIV
# bad: EBAY
# bad: FE
# bad: FIS
# bad: EPAM
# bad: ESS
# bad: HLT
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
# bad: FISV
# bad: EL
# bad: ETR
# bad: FOXA
# bad: ES
# bad: EQR
# bad: FTV
# bad: GE
# bad: FSLR
# bad: FCX
# bad: GPC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
# bad: IT
# bad: FLT
# bad: HES
# bad: HAL
# bad: ISRG
# bad: GS
# bad: XOM
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
# bad: FRT
# bad: GRMN
# bad: BEN
# bad: GNRC
# bad: HBAN
# bad: CVS
# bad: FOX
# bad: HCA
# bad: ICE
# bad: FMC
# bad: FDS
# bad: FTNT
# bad: HSIC
# bad: HAS
# bad: EMR
# bad: FAST
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: IR
# bad: IEX
# [*********************100%***********************]  1 of 1 completed
# bad: F
# bad: EFX
# bad: HIG
# bad: GILD
# bad: K
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
# bad: IFF
# bad: LDOS
# bad: HST
# bad: MTB
# bad: GIS
# bad: IPG
# bad: HRL
# bad: LMT
# bad: KEY
# bad: HPQ
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
# bad: INTC
# bad: HON
# bad: HSY
# bad: HUM
# bad: ITW
# bad: MPC
# bad: GL
# bad: GM
# bad: IQV
# bad: HD
# bad: GEN
# bad: INCY
# bad: HII
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
# bad: GD
# bad: J
# bad: IBM
# bad: FRC
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: HOLX
# bad: ILMN
# bad: IVZ
# bad: LOW
# bad: HPE
# bad: LH
# bad: LNC
# bad: MSFT
# bad: JPM
# bad: KHC
# bad: MOH
# bad: HWM
# bad: TAP
# bad: MAS
# bad: PEAK
# bad: IDXX
# bad: KLAC
# bad: JKHY
# bad: IRM
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
# bad: LYV
# bad: JNJ
# bad: IP
# bad: KMI
# bad: MU
# bad: GPN
# bad: LW
# bad: MRO
# bad: KIM
# bad: MCHP
# bad: KMB
# bad: LKQ
# bad: MAR
# bad: MMC
# bad: LEN
# bad: KDP
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: ORLY
# bad: LINbad: LUMN
#
# bad: MCD
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: KR
# bad: LYB
# bad: JBHT
# bad: KEYS
# bad: NFLX
# bad: MKTX
# bad: MTCH
# bad: NWSA
# bad: MLM
# bad: LHX
# bad: JCI
# bad: MSCI
# bad: INTU
# bad: MKC
# bad: L
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: MHK
# bad: ON
# bad: MDT
# bad: META
# bad: MRNA
# bad: JNPR
# bad: MPWR
# bad: MSI
# bad: NCLH
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
# bad: MS
# bad: MAA
# bad: MET
# bad: MRK
# bad: ORCL
# bad: RTX
# bad: MDLZ
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
# bad: LRCX
# bad: NVDA
# bad: PM
# bad: MGM
# bad: ROL
# bad: MCK
# bad: OGN
# bad: MNST
# bad: NEE
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
# bad: PARA
# [*********************100%***********************]  1 of 1 completed
# bad: PAYX
# bad: PCG
# bad: NVR
# bad: NXPI
# bad: NKE
# bad: PHM
# bad: NWL
# bad: NDAQ
# bad: PXD
# bad: MOS
# bad: MA
# bad: NSC
# bad: NOC
# bad: NUE
# bad: RJF
# bad: MCO
# bad: PNR
# bad: PYPL
# bad: OKE
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: RL
# bad: PPG
# bad: RHI
# bad: PCAR
# bad: OXY
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
# bad: MTD
# bad: PPL
# bad: NTRS
# [*********************100%***********************]  1 of 1 completed
#
#
# 1 Failed download:
# - CDAY: Data doesn't exist for startDate = 1483246800, endDate = 1493524800
# bad: PSX
# bad: NI
#
# bad: QRVO
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: PEG
# bad: PTC
# bad: PKI
# bad: INVH
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: PLD
# bad: REGN
# bad: RCL
# bad: PSA
# bad: PH
# bad: PKG
# bad: NDSN
# bad: SBAC
# bad: SHW
# bad: SIVB
# bad: PEP
# bad: PWR
# bad: NWS
# bad: PFE
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: REG
# bad: UDR
# bad: POOL
# bad: NEM
# bad: PNW
# [*********************100%***********************]  1 of 1 completed
#
#
# 1 Failed download:
# - CARR: Data doesn't exist for startDate = 1483246800, endDate = 1493524800
# bad: PFG
# bad: RF
#
# bad: ROST
#
# bad: TGT
#
# bad: O
# bad: PNC
# bad: SWK
# bad: SEDG
# bad: TFX
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
# bad: NTAP
# bad: PAYC
# [*********************100%***********************]  1 of 1 completed
#
# bad: SJM
# bad: TMUS
# bad: ROP
# bad: SYY
# bad: NRG
# bad: TXN
# bad: TSLA
# bad: SPG
# bad: RSG
# bad: TROW
# bad: QCOM
# bad: SYK
# bad: CRM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
# bad: DGX
# bad: SNA
# bad: SBUX
# bad: TMO
# bad: SYF
# bad: TRV
# bad: TER
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
# bad: TFC
# bad: VLO
# bad: TPR
# bad: SRE
# bad: NOW
# bad: STX
# bad: TRMB
# bad: TTWO
# bad: OTIS
# bad: TDG
# bad: PG
# bad: PGR
# bad: PRU
# bad: STLD
# bad: ROK
# bad: TT
# [*********************100%***********************]  1 of 1 completed
#
# bad: URI
#
# bad: VRTX
#
# bad: SEE
#
# bad: TRGP
#
# bad: UAL
#
# bad: STT
#
# bad: VICI
#
# bad: RMD
#
# bad: ULTA
#
# bad: YUM
#
# bad: WHR
# bad: TEL
# bad: UNH
# bad: SNPS
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bad: TSCO
# bad: WY
# bad: TXT
# bad: SO
# bad: TDY
# bad: VMC
# bad: UNP
# bad: VZ
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
# bad: WEC
# [*********************100%***********************]  1 of 1 completed
# bad: LUV
# bad: UHS
# bad: TJX
# bad: LVS
# bad: WM
# bad: OMC
# bad: VRSN
# bad: WST
# bad: SWKS
# bad: WTW
# bad: TSN
# bad: GWW
# bad: WELL
# [*********************100%***********************]  1 of 1 completed
#
#
#
#
#
#
#
#
#
#
#
#
# bad: V
# bad: STE
# bad: SBNY
# bad: USB
# [*********************100%***********************]  1 of 1 completed
#
#
#
# bad: ODFL
# bad: WYNN
# bad: UPS
# [*********************100%***********************]  1 of 1 completed
#
#
# bad: ZBRA
# bad: VTR
# bad: ZION
# bad: WBA
# bad: XEL
# bad: VFC
# bad: WAT
# bad: ZTS
# bad: WBD
# bad: WFC
# bad: ZBH
# bad: VTRS
# bad: WMB
# bad: WRK
# bad: VRSK
# bad: WMT
# bad: WDC
# bad: SPGI
# [*********************100%***********************]  1 of 1 completed
# bad: SLB
# bad: WAB
# bad: XYL
# The threaded script took 0 minutes and 15 seconds to run.
# 503 stocks failed:  ['ALL', 'AKAM', 'GOOGL', 'AMZN', 'LNT', 'AAP', 'MMM', 'AES', 'ADBE', 'A', 'GOOG', 'ADP', 'AMT', 'ABC', 'ABBV', 'AXP', 'AMGN', 'ADM', 'APA', 'AON', 'BBY', 'AOS', 'ALLE', 'ADI', 'AAPL', 'ACN', 'ACGL', 'AWK', 'AMP', 'APH', 'ARE', 'ATVI', 'APD', 'AAL', 'BAC', 'AJG', 'AFL', 'ALB', 'BIO', 'ATO', 'AMCR', 'AIZ', 'CDW', 'ALGN', 'CHRW', 'ALK', 'WRB', 'ANET', 'AEE', 'ABT', 'BKNG', 'BBWI', 'CBOE', 'BF-B', 'AZO', 'MO', 'BXP', 'APTV', 'BIIB', 'AMD', 'AMAT', 'CPB', 'BMY', 'ANSS', 'AIG', 'BDX', 'AVY', 'CSCO', 'CI', 'BAX', 'AEP', 'CTLT', 'BK', 'T', 'CDAY', 'CPT', 'CLX', 'BRO', 'CTAS', 'AME', 'CE', 'BSX', 'BRK-B', 'CNC', 'CB', 'ADSK', 'BKR', 'DHR', 'COF', 'BALL', 'CMCSA', 'CDNS', 'CFG', 'CBRE', 'KO', 'SCHW', 'CF', 'BA', 'CCI', 'CHD', 'BLK', 'CZR', 'CME', 'CSX', 'CVX', 'CPRT', 'AVGO', 'CNP', 'DRI', 'CSGP', 'DD', 'CTVA', 'CARR', 'CHTR', 'COST', 'CCL', 'GLW', 'CL', 'KMX', 'COO', 'AVB', 'TECH', 'D', 'BWA', 'DAL', 'CMS', 'DPZ', 'ED', 'CAH', 'CAG', 'BR', 'ETN', 'XRAY', 'CTSH', 'STZ', 'CMG', 'DTE', 'CINF', 'DHI', 'DISH', 'CTRA', 'EXR', 'CMA', 'CMI', 'DVN', 'COP', 'C', 'DFS', 'EXPE', 'DUK', 'DXC', 'DLR', 'CRL', 'DOV', 'FITB', 'EW', 'CAT', 'LLY', 'ECL', 'EQIX', 'DOW', 'EVRG', 'EMN', 'FANG', 'EQT', 'ETSY', 'DXCM', 'EA', 'EXPD', 'DE', 'ELV', 'EOG', 'DIS', 'DLTR', 'EXC', 'CEG', 'ENPH', 'DVA', 'EIX', 'DG', 'GEHC', 'RE', 'FDX', 'FFIV', 'EBAY', 'FE', 'FIS', 'EPAM', 'ESS', 'HLT', 'FISV', 'EL', 'ETR', 'FOXA', 'ES', 'EQR', 'FTV', 'GE', 'FSLR', 'FCX', 'GPC', 'IT', 'FLT', 'HES', 'HAL', 'ISRG', 'GS', 'XOM', 'FRT', 'GRMN', 'BEN', 'GNRC', 'HBAN', 'CVS', 'FOX', 'HCA', 'ICE', 'FMC', 'FDS', 'FTNT', 'HSIC', 'HAS', 'EMR', 'FAST', 'IR', 'IEX', 'F', 'EFX', 'HIG', 'GILD', 'K', 'IFF', 'LDOS', 'HST', 'MTB', 'GIS', 'IPG', 'HRL', 'LMT', 'KEY', 'HPQ', 'INTC', 'HON', 'HSY', 'HUM', 'ITW', 'MPC', 'GL', 'GM', 'IQV', 'HD', 'GEN', 'INCY', 'HII', 'GD', 'J', 'IBM', 'FRC', 'HOLX', 'ILMN', 'IVZ', 'LOW', 'HPE', 'LH', 'LNC', 'MSFT', 'JPM', 'KHC', 'MOH', 'HWM', 'TAP', 'MAS', 'PEAK', 'IDXX', 'KLAC', 'JKHY', 'IRM', 'LYV', 'JNJ', 'IP', 'KMI', 'MU', 'GPN', 'LW', 'MRO', 'KIM', 'MCHP', 'KMB', 'LKQ', 'MAR', 'MMC', 'LEN', 'KDP', 'ORLY', 'LIN', 'LUMN', 'MCD', 'KR', 'LYB', 'JBHT', 'KEYS', 'NFLX', 'MKTX', 'MTCH', 'NWSA', 'MLM', 'LHX', 'JCI', 'MSCI', 'INTU', 'MKC', 'L', 'MHK', 'ON', 'MDT', 'META', 'MRNA', 'JNPR', 'MPWR', 'MSI', 'NCLH', 'MS', 'MAA', 'MET', 'MRK', 'ORCL', 'RTX', 'MDLZ', 'LRCX', 'NVDA', 'PM', 'MGM', 'ROL', 'MCK', 'OGN', 'MNST', 'NEE', 'PARA', 'PAYX', 'PCG', 'NVR', 'NXPI', 'NKE', 'PHM', 'NWL', 'NDAQ', 'PXD', 'MOS', 'MA', 'NSC', 'NOC', 'NUE', 'RJF', 'MCO', 'PNR', 'PYPL', 'OKE', 'RL', 'PPG', 'RHI', 'PCAR', 'OXY', 'MTD', 'PPL', 'NTRS', 'PSX', 'NI', 'QRVO', 'PEG', 'PTC', 'PKI', 'INVH', 'PLD', 'REGN', 'RCL', 'PSA', 'PH', 'PKG', 'NDSN', 'SBAC', 'SHW', 'SIVB', 'PEP', 'PWR', 'NWS', 'PFE', 'REG', 'UDR', 'POOL', 'NEM', 'PNW', 'PFG', 'RF', 'ROST', 'TGT', 'O', 'PNC', 'SWK', 'SEDG', 'TFX', 'NTAP', 'PAYC', 'SJM', 'TMUS', 'ROP', 'SYY', 'NRG', 'TXN', 'TSLA', 'SPG', 'RSG', 'TROW', 'QCOM', 'SYK', 'CRM', 'DGX', 'SNA', 'SBUX', 'TMO', 'SYF', 'TRV', 'TER', 'TFC', 'VLO', 'TPR', 'SRE', 'NOW', 'STX', 'TRMB', 'TTWO', 'OTIS', 'TDG', 'PG', 'PGR', 'PRU', 'STLD', 'ROK', 'TT', 'TYL', 'URI', 'VRTX', 'SEE', 'TRGP', 'UAL', 'STT', 'VICI', 'RMD', 'ULTA', 'YUM', 'WHR', 'TEL', 'UNH', 'SNPS', 'TSCO', 'WY', 'TXT', 'SO', 'TDY', 'VMC', 'UNP', 'VZ', 'WEC', 'LUV', 'UHS', 'TJX', 'LVS', 'WM', 'OMC', 'VRSN', 'WST', 'SWKS', 'WTW', 'TSN', 'GWW', 'WELL', 'V', 'STE', 'SBNY', 'USB', 'ODFL', 'WYNN', 'UPS', 'ZBRA', 'VTR', 'ZION', 'WBA', 'XEL', 'VFC', 'WAT', 'ZTS', 'WBD', 'WFC', 'ZBH', 'VTRS', 'WMB', 'WRK', 'VRSK', 'WMT', 'WDC', 'SPGI', 'SLB', 'WAB', 'XYL']

# %%
historial_stock_data_files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 historial_stock_data_files
#
# NameError: name 'historial_stock_data_files' is not defined

# %%
historial_stock_data_files = glob.glob(f"{data_dir}/*.csv")
highest_day_list = []
for files in historial_stock_data_files:
    price = pd.read_csv(files, index_col="Date", parse_dates = True)
    ticker = os.path.splitext(os.path.basename(files))[0]
    price_close = price[["Close"]]
    highest_day = price_close.idxmax()[0]
    highest_price = price_close.max()[0]
    print(f"{price_close}:{highest_day}:{highest_price}")
    # highest_day_list.append(
    #     pd.DataFrame({"highest_day": highest_day, "ticker": ticker, "highest_price": highest_price }))

# %%
highest_day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 highest_day
#
# NameError: name 'highest_day' is not defined

# %%
df = pd.concat(highest_day_list).reset_index(drop=True)
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 11
#       8     highest_price = price_close.max()[0]
#       9     highest_day_list.append(
#      10         pd.DataFrame({"highest_day": [highest_day], "ticker": [ticker], "highest_price": [highest_price] }))
# ---> 11 df = pd.concat(highest_day_list).reset_index(drop=True)
#      12 print(df.shape)
#      13 df.head()
#
# File C:\work\p-lenz-portal\CarloShaw\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\work\p-lenz-portal\CarloShaw\venv\lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File C:\work\p-lenz-portal\CarloShaw\venv\lib\site-packages\pandas\core\reshape\concat.py:425, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     422     objs = list(objs)
#     424 if len(objs) == 0:
# --> 425     raise ValueError("No objects to concatenate")
#     427 if keys is None:
#     428     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate
